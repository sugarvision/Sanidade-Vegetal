# %% [markdown]
# # Sprint 2: Modify Pipeline
#
# Run the feature extraction pipeline and validation tests.

# %%
# !python ../src/feature_extraction_pipeline.py

# %%
# !python ../src/test_run_pipeline.py
